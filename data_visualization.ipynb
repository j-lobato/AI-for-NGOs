# %% [markdown]
# <a href="https://colab.research.google.com/github/j-lobato/AI-for-NGOs/blob/main/data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
# 1 scatter plot of african countries by GDP per capita and life expectancy

df = px.data.gapminder()
africa = df[df.continent == 'Africa']

# %%
fig = px.scatter(africa.query("year==2007"), x="gdpPercap", y="lifeExp",
	         size="pop", color="country",
                 hover_name="country", log_x=True, size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a7be5f47-62e0-4f38-af43-83869749eb3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7be5f47-62e0-4f38-af43-83869749eb3a")) {                    Plotly.newPlot(                        "a7be5f47-62e0-4f38-af43-83869749eb3a",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Algeria<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","hovertext":["Algeria"],"legendgroup":"Algeria","marker":{"color":"#636efa","size":[33333216],"sizemode":"area","sizeref":37508.65666666667,"symbol":"circle"},"mode":"markers","name":"Algeria","orientation":"v","showlegend":true,"x":[6223.367465],"xaxis":"x","y":[72.301],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Angola<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","hovertext":["Angola"],"legendgroup":"Angola","marker":{"color":"#EF553B","size":[12420476],"sizemode":"area","sizeref":37508.65666666667,"symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":[4797.231267],"xaxis":"x","y":[42.731],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Benin<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","hovertext":["Benin"],"legendgroup":"Benin","marker":{"color":"#00cc96","size":[8078314],"sizemode":"area","sizeref":37508.65666666667,"symbol":"circle"},"mode":"markers","name":"Benin","orientation":"v","showlegend":true,"x":[1441.284873],"xaxis":"x","y":[56.728],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Botswana<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","hovertext":["Botswana"],"legendgroup":"Botswana","marker":{"color":"#ab63fa","size":[1639131],"sizemode":"area","sizeref":37508.65666666667,"symbol":"circle"},"mode":"markers","name":"Botswana","orientation":"v","showlegend":true,"x":[12569.85177],"xaxis":"x","y":[50.728],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Burkina Faso<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","hovertext":["Burkina Faso"],"legendgroup":"Burkina Faso","marker":{"color":"#FFA15A","size":[14326203],"sizemode":"area","sizeref":37508.65666666667,"symbol":"circle"},"mode":"markers","name":"Burkina Faso","orientation":"v","showlegend":true,"x":[1217.032994],"xaxis":"x","y":[52.295],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Burundi<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","hovertext":["Burundi"],"legendgroup":"Burundi","marker":{"color":"#19d3f3","size":[8390505],"sizemode":"area","sizeref":37508.65666666667,"symbol":"circle"},"mode":"markers","name":"Burundi","orientation":"v","showlegend":true,"x":[430.0706916],"xaxis":"x","y":[49.58],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Cameroon<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","hovertext":["Cameroon"],"legendgroup":"Cameroon","marker":{"color":"#FF6692","size":[17696293],"sizemode":"area","sizeref":37508.65666666667,"symbol":"circle"},"mode":"markers","name":"Cameroon","orientation":"v","showlegend":true,"x":[2042.09524],"xaxis":"x","y":[50.43],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Central African Republic<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","hovertext":["Central African Republic"],"legendgroup":"Central African Republic","marker":{"color":"#B6E880","size":[4369038],"sizemode":"area","sizeref":37508.65666666667,"symbol":"circle"},"mode":"markers","name":"Central African Republic","ori ...

# %%
## 2 Interactive visualization of the above

fig=px.scatter(africa, x="gdpPercap", y="pop", animation_frame="year", animation_group="country",height=600,width=1000,
               size="gdpPercap",
           color="country", hover_name="country",size_max=150,log_x=True,log_y=True,
               range_x=[200,22000], range_y=[30000,136031164],)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d6fc9ad8-c928-4ca5-9f97-53950cb9b54c" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6fc9ad8-c928-4ca5-9f97-53950cb9b54c")) {                    Plotly.newPlot(                        "d6fc9ad8-c928-4ca5-9f97-53950cb9b54c",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Algeria<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Algeria"],"ids":["Algeria"],"legendgroup":"Algeria","marker":{"color":"#636efa","size":[2449.008185],"sizemode":"area","sizeref":0.9756094115555555,"symbol":"circle"},"mode":"markers","name":"Algeria","orientation":"v","showlegend":true,"x":[2449.008185],"xaxis":"x","y":[9279525],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Angola<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Angola"],"ids":["Angola"],"legendgroup":"Angola","marker":{"color":"#EF553B","size":[3520.610273],"sizemode":"area","sizeref":0.9756094115555555,"symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":[3520.610273],"xaxis":"x","y":[4232095],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Benin<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Benin"],"ids":["Benin"],"legendgroup":"Benin","marker":{"color":"#00cc96","size":[1062.7522],"sizemode":"area","sizeref":0.9756094115555555,"symbol":"circle"},"mode":"markers","name":"Benin","orientation":"v","showlegend":true,"x":[1062.7522],"xaxis":"x","y":[1738315],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Botswana<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Botswana"],"ids":["Botswana"],"legendgroup":"Botswana","marker":{"color":"#ab63fa","size":[851.2411407],"sizemode":"area","sizeref":0.9756094115555555,"symbol":"circle"},"mode":"markers","name":"Botswana","orientation":"v","showlegend":true,"x":[851.2411407],"xaxis":"x","y":[442308],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Burkina Faso<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Burkina Faso"],"ids":["Burkina Faso"],"legendgroup":"Burkina Faso","marker":{"color":"#FFA15A","size":[543.2552413],"sizemode":"area","sizeref":0.9756094115555555,"symbol":"circle"},"mode":"markers","name":"Burkina Faso","orientation":"v","showlegend":true,"x":[543.2552413],"xaxis":"x","y":[4469979],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Burundi<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Burundi"],"ids":["Burundi"],"legendgroup":"Burundi","marker":{"color":"#19d3f3","size":[339.2964587],"sizemode":"area","sizeref":0.9756094115555555,"symbol":"circle"},"mode":"markers","name":"Burundi","orientation":"v","showlegend":true,"x":[339.2964587],"xaxis":"x","y":[2445618],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Cameroon<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Cameroon"],"ids":["Cameroon"],"legendgroup":"Cameroon","marker":{"color":"#FF6692","size":[1172.667655],"sizemode":"area","sizeref":0.9756094115555555,"symbol":"circle"},"mode":"markers","name":"Cameroon","orientation":"v","showlegend":true,"x":[1172.667655],"xaxis":"x","y":[5009067],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Central African Republic<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Central African Republic"],"ids":["Central African Republic"],"legendgroup":"Central Afri ...

# %%
africa7 = africa[africa7.year== 2007]

# %%
#
fig = px.bar(africa7, x="country", y="gdpPercap",
             hover_data=["pop", "gdpPercap"],
             title='GDP per Capita in African Countries')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="18df4a06-36ac-48ed-b960-6b8111a98a36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18df4a06-36ac-48ed-b960-6b8111a98a36")) {                    Plotly.newPlot(                        "18df4a06-36ac-48ed-b960-6b8111a98a36",                        [{"alignmentgroup":"True","customdata":[[33333216],[12420476],[8078314],[1639131],[14326203],[8390505],[17696293],[4369038],[10238807],[710960],[64606759],[3800610],[18013409],[496374],[80264543],[551201],[4906585],[76511887],[1454867],[1688359],[22873338],[9947814],[1472041],[35610177],[2012649],[3193942],[6036914],[19167654],[13327079],[12031795],[3270065],[1250882],[33757175],[19951656],[2055080],[12894865],[135031164],[798094],[8860588],[199579],[12267493],[6144562],[9118773],[43997828],[42292929],[1133066],[38139640],[5701579],[10276158],[29170398],[11746035],[12311143]],"hovertemplate":"country=%{x}<br>gdpPercap=%{y}<br>pop=%{customdata[0]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Algeria","Angola","Benin","Botswana","Burkina Faso","Burundi","Cameroon","Central African Republic","Chad","Comoros","Congo, Dem. Rep.","Congo, Rep.","Cote d'Ivoire","Djibouti","Egypt","Equatorial Guinea","Eritrea","Ethiopia","Gabon","Gambia","Ghana","Guinea","Guinea-Bissau","Kenya","Lesotho","Liberia","Libya","Madagascar","Malawi","Mali","Mauritania","Mauritius","Morocco","Mozambique","Namibia","Niger","Nigeria","Reunion","Rwanda","Sao Tome and Principe","Senegal","Sierra Leone","Somalia","South Africa","Sudan","Swaziland","Tanzania","Togo","Tunisia","Uganda","Zambia","Zimbabwe"],"xaxis":"x","y":[6223.367465,4797.231267,1441.284873,12569.85177,1217.032994,430.0706916,2042.09524,706.016537,1704.063724,986.1478792,277.5518587,3632.557798,1544.750112,2082.4815670000007,5581.180998,12154.08975,641.3695236000002,690.8055759,13206.48452,752.7497265,1327.60891,942.6542111,579.2317429999998,1463.249282,1569.331442,414.5073415,12057.49928,1044.770126,759.3499101,1042.581557,1803.151496,10956.99112,3820.17523,823.6856205,4811.060429,619.6768923999998,2013.977305,7670.122558,863.0884639000002,1598.435089,1712.472136,862.5407561000002,926.1410683,9269.657808,2602.394995,4513.480643,1107.482182,882.9699437999999,7092.923025,1056.380121,1271.211593,469.70929810000007],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"t ...

# %%
africa.head()

# %%
df= pd.read_csv('world_country_gdp_usd.csv')
px.choropleth(df,
              locations = 'Country Code',
              color=df["GDP_per_capita_USD"],
              animation_frame="year",
              color_continuous_scale = [[0, '#751c35'],
                      [0.2, '#999900'],
                      [0.7, '#006400'],
                      [1, '#006400'],
                     ],
              scope = 'africa',
              range_color=(0, 20000),
              title='Africa GDP per Capita',
              height=800

             )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fd32bb5c-853c-4d2d-9632-f8f9b72f148d" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd32bb5c-853c-4d2d-9632-f8f9b72f148d")) {                    Plotly.newPlot(                        "fd32bb5c-853c-4d2d-9632-f8f9b72f148d",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"year=1960<br>Country Code=%{location}<br>GDP_per_capita_USD=%{z}<extra></extra>","locations":["ABW","AFE","AFG","AFW","AGO","ALB","AND","ARB","ARE","ARG","ARM","ASM","ATG","AUS","AUT","AZE","BDI","BEL","BEN","BFA","BGD","BGR","BHR","BHS","BIH","BLR","BLZ","BMU","BOL","BRA","BRB","BRN","BTN","BWA","CAF","CAN","CEB","CHE","CHI","CHL","CHN","CIV","CMR","COD","COG","COL","COM","CPV","CRI","CSS","CUB","CUW","CYM","CYP","CZE","DEU","DJI","DMA","DNK","DOM","DZA","EAP","EAR","EAS","ECA","ECS","ECU","EGY","EMU","ERI","ESP","EST","ETH","EUU","FCS","FIN","FJI","FRA","FRO","FSM","GAB","GBR","GEO","GHA","GIB","GIN","GMB","GNB","GNQ","GRC","GRD","GRL","GTM","GUM","GUY","HIC","HKG","HND","HPC","HRV","HTI","HUN","IBD","IBT","IDA","IDB","IDN","IDX","IMN","IND","INX","IRL","IRN","IRQ","ISL","ISR","ITA","JAM","JOR","JPN","KAZ","KEN","KGZ","KHM","KIR","KNA","KOR","KWT","LAC","LAO","LBN","LBR","LBY","LCA","LCN","LDC","LIC","LIE","LKA","LMC","LMY","LSO","LTE","LTU","LUX","LVA","MAC","MAF","MAR","MCO","MDA","MDG","MDV","MEA","MEX","MHL","MIC","MKD","MLI","MLT","MMR","MNA","MNE","MNG","MNP","MOZ","MRT","MUS","MWI","MYS","NAC","NAM","NCL","NER","NGA","NIC","NLD","NOR","NPL","NRU","NZL","OED","OMN","OSS","PAK","PAN","PER","PHL","PLW","PNG","POL","PRE","PRI","PRK","PRT","PRY","PSE","PSS","PST","PYF","QAT","ROU","RUS","RWA","SAS","SAU","SDN","SEN","SGP","SLB","SLE","SLV","SMR","SOM","SRB","SSA","SSD","SSF","SST","STP","SUR","SVK","SVN","SWE","SWZ","SXM","SYC","SYR","TCA","TCD","TEA","TEC","TGO","THA","TJK","TKM","TLA","TLS","TMN","TON","TSA","TSS","TTO","TUN","TUR","TUV","TZA","UGA","UKR","UMC","URY","USA","UZB","VCT","VEN","VGB","VIR","VNM","VUT","WLD","WSM","XKX","YEM","ZAF","ZMB","ZWE"],"name":"","z":[null,162.7263255,59.7732337,107.9307217,null,null,null,null,null,null,null,null,null,1810.61923,935.4604269,null,70.0519099,1273.691659,93.02270027,68.4247344,89.03523943,null,null,1550.267699,null,null,304.9038598,1902.402119,102.2377224,235.9468833,null,null,null,60.493958,74.68734697,2259.294285,null,1787.360348,null,505.3493255,89.52054151,155.8996328,118.6431452,220.3139899,129.3703364,251.0415229,null,null,381.3636818,448.2564174,null,null,null,null,null,null,null,null,null,204.1148714,246.3037513,90.90209241,161.1653515,148.4236231,null,null,455.4623888,null,923.1873412,null,396.3922533,null,null,null,null,1179.353011,285.4742861,1334.689512,null,null,282.4171795,1397.594803,null,183.4280075,null,null,null,null,null,520.3227443,null,null,252.7561712,null,297.6764225,1372.007466,429.4428744,164.6443995,107.3399177,null,70.66108456,null,170.4505039,158.1254075,97.20955584,100.2031755,null,98.85275686,null,82.18860274,null,685.6147124,191.680825,231.0258708,1414.982269,1229.174748,804.4926233,429.2541461,null,475.3190756,null,97.44550102,null,111.3424408,null,241.5391631,158.2493033,null,348.6692686,null,null,null,null,null,384.4166116,null,null,null,142.7796219,92.09921949,151.6954418,41.30036454,174.9208106,null,2242.015817,null,null,null,164.800827,null,null,131.9931654,null,null,345.2305408,null,155.6096657,null,null,null,null,null,null,null,null,null,null,null,44.52394299,234.9388974,2939.448335,null,null,132.651771,92.9604656,126.248168,1068.784587,1441.75566,50.30493772,null,2312.949992,1335.424217,null,null,83.33794593,474.0906704,253.2649213,286.1043301,null,102.1766587,null,111.5900363,717.5148431,null,360.4992985,null,null,null,1387.393967,null,null ...

# %%
##  visualization of the whole world

fig=px.scatter(df, x="gdpPercap", y="pop", animation_frame="year", animation_group="continent",height=600,width=1000,
               size="gdpPercap",
           color="country", hover_name="country",size_max=150,log_x=True,log_y=True,
               range_x=[200,22000], range_y=[30000,136031164])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5dd79781-0e5f-4ea4-a870-29d738cbe457" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5dd79781-0e5f-4ea4-a870-29d738cbe457")) {                    Plotly.newPlot(                        "5dd79781-0e5f-4ea4-a870-29d738cbe457",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Afghanistan<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Afghanistan"],"ids":["Asia"],"legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[779.4453145],"sizemode":"area","sizeref":5.045472573333333,"symbol":"circle"},"mode":"markers","name":"Afghanistan","orientation":"v","showlegend":true,"x":[779.4453145],"xaxis":"x","y":[8425333],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Albania<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Albania"],"ids":["Europe"],"legendgroup":"Albania","marker":{"color":"#EF553B","size":[1601.056136],"sizemode":"area","sizeref":5.045472573333333,"symbol":"circle"},"mode":"markers","name":"Albania","orientation":"v","showlegend":true,"x":[1601.056136],"xaxis":"x","y":[1282697],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Algeria<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Algeria"],"ids":["Africa"],"legendgroup":"Algeria","marker":{"color":"#00cc96","size":[2449.008185],"sizemode":"area","sizeref":5.045472573333333,"symbol":"circle"},"mode":"markers","name":"Algeria","orientation":"v","showlegend":true,"x":[2449.008185],"xaxis":"x","y":[9279525],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Angola<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Angola"],"ids":["Africa"],"legendgroup":"Angola","marker":{"color":"#ab63fa","size":[3520.610273],"sizemode":"area","sizeref":5.045472573333333,"symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":[3520.610273],"xaxis":"x","y":[4232095],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Argentina<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Argentina"],"ids":["Americas"],"legendgroup":"Argentina","marker":{"color":"#FFA15A","size":[5911.315053],"sizemode":"area","sizeref":5.045472573333333,"symbol":"circle"},"mode":"markers","name":"Argentina","orientation":"v","showlegend":true,"x":[5911.315053],"xaxis":"x","y":[17876956],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Australia<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Australia"],"ids":["Oceania"],"legendgroup":"Australia","marker":{"color":"#19d3f3","size":[10039.59564],"sizemode":"area","sizeref":5.045472573333333,"symbol":"circle"},"mode":"markers","name":"Australia","orientation":"v","showlegend":true,"x":[10039.59564],"xaxis":"x","y":[8691212],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Austria<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Austria"],"ids":["Europe"],"legendgroup":"Austria","marker":{"color":"#FF6692","size":[6137.076492],"sizemode":"area","sizeref":5.045472573333333,"symbol":"circle"},"mode":"markers","name":"Austria","orientation":"v","showlegend":true,"x":[6137.076492],"xaxis":"x","y":[6927772],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=Bahrain<br>year=1952<br>gdpPercap=%{marker.size}<br>pop=%{y}<extra></extra>","hovertext":["Bahrain"],"ids":["Asia"],"legendgroup":"Bahrain","marker":{"color":"#B6E880","size":[9867.084765],"sizemo ...

# %%
df.Year.value_counts()
# Out:
# 14    31
# Name: Year, dtype: int64

# %%
## 4 Ebola in West Africa - from plotly express

import plotly.graph_objects as go

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_ebola.csv')
df.head()

colors = ['rgb(239,243,255)','rgb(189,215,231)','rgb(107,174,214)','rgb(33,113,181)']
months = {6:'June',7:'July',8:'Aug',9:'Sept'}

fig = go.Figure()

for i in range(6,10)[::-1]:
    df_month = df.query('Month == %d' %i)
    fig.add_trace(go.Scattergeo(
            lon = df_month['Lon'],
            lat = df_month['Lat'],
            text = df_month['Value'],
            name = months[i],
            marker = dict(
                size = df_month['Value']/50,
                color = colors[i-6],
                line_width = 0
            )))

df_sept = df.query('Month == 9')
fig['data'][0].update(mode='markers+text', textposition='bottom center',
                      text=df_sept['Value'].map('{:.0f}'.format).astype(str)+' '+\
                      df_sept['Country'])

# Inset
fig.add_trace(go.Choropleth(
        locationmode = 'country names',
        locations = df_sept['Country'],
        z = df_sept['Value'],
        text = df_sept['Country'],
        colorscale = [[0,'rgb(0, 0, 0)'],[1,'rgb(0, 0, 0)']],
        autocolorscale = False,
        showscale = False,
        geo = 'geo2'
    ))
fig.add_trace(go.Scattergeo(
        lon = [21.0936],
        lat = [7.1881],
        text = ['Africa'],
        mode = 'text',
        showlegend = False,
        geo = 'geo2'
    ))

fig.update_layout(
    title = go.layout.Title(
        text = 'Ebola cases reported by month in West Africa 2014<br> \
Source: <a href="https://data.hdx.rwlabs.org/dataset/rowca-ebola-cases">\
HDX</a>'),
    geo = go.layout.Geo(
        resolution = 50,
        scope = 'africa',
        showframe = False,
        showcoastlines = True,
        landcolor = "rgb(229, 229, 229)",
        countrycolor = "white" ,
        coastlinecolor = "white",
        projection_type = 'mercator',
        lonaxis_range= [ -15.0, -5.0 ],
        lataxis_range= [ 0.0, 12.0 ],
        domain = dict(x = [ 0, 1 ], y = [ 0, 1 ])
    ),
    geo2 = go.layout.Geo(
        scope = 'africa',
        showframe = False,
        landcolor = "rgb(229, 229, 229)",
        showcountries = False,
        domain = dict(x = [ 0, 0.6 ], y = [ 0, 0.6 ]),
        bgcolor = 'rgba(255, 255, 255, 0.0)',
    ),
    legend_traceorder = 'reversed'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="17a0e859-3fdd-430f-b554-c7fb2062a0bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17a0e859-3fdd-430f-b554-c7fb2062a0bd")) {                    Plotly.newPlot(                        "17a0e859-3fdd-430f-b554-c7fb2062a0bd",                        [{"lat":[9.95,6.43,14.5,8.46],"lon":[-9.7,-9.43,-14.45,-11.78],"marker":{"color":"rgb(33,113,181)","line":{"width":0},"size":[20.44,67.24,0.06,38.8]},"name":"Sept","text":["1022 Guinea","3362 Liberia","3 Senegal","1940 Sierra Leone"],"type":"scattergeo","mode":"markers+text","textposition":"bottom center"},{"lat":[9.95,6.43,14.5,8.46],"lon":[-9.7,-9.43,-14.45,-11.78],"marker":{"color":"rgb(107,174,214)","line":{"width":0},"size":[15.42,27.9,0.02,24.32]},"name":"Aug","text":[771.0,1395.0,1.0,1216.0],"type":"scattergeo"},{"lat":[9.95,6.43,8.46],"lon":[-9.7,-9.43,-11.78],"marker":{"color":"rgb(189,215,231)","line":{"width":0},"size":[9.2,6.58,10.66]},"name":"July","text":[460.0,329.0,533.0],"type":"scattergeo"},{"lat":[9.95,6.43,8.46],"lon":[-9.7,-9.43,-11.78],"marker":{"color":"rgb(239,243,255)","line":{"width":0},"size":[8.26,2.14,4.78]},"name":"June","text":[413.0,107.0,239.0],"type":"scattergeo"},{"autocolorscale":false,"colorscale":[[0,"rgb(0, 0, 0)"],[1,"rgb(0, 0, 0)"]],"geo":"geo2","locationmode":"country names","locations":["Guinea","Liberia","Senegal","Sierra Leone"],"showscale":false,"text":["Guinea","Liberia","Senegal","Sierra Leone"],"z":[1022.0,3362.0,3.0,1940.0],"type":"choropleth"},{"geo":"geo2","lat":[7.1881],"lon":[21.0936],"mode":"text","showlegend":false,"text":["Africa"],"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outl ...
